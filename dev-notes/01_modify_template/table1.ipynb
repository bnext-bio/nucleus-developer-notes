# %%
from src.cdk.analysis.cytosol import platereader as pr
import pandas as pd

import seaborn as sns
import seaborn.objects as so

import matplotlib.pyplot as plt
import ipywidgets as widgets

import src.cdk.logging

pr.plot_setup()

data, platemap = pr.load_platereader_data("tests/test_data/cytation_dna_sweep.txt", "tests/test_data/platemap.csv")

# %%
#| label: table1-1
platemap
# Out:
#    Well     Experiment                   Name                 DNA Template  \
# 0    B1  Concentration          pT7-deGFP 100            pT7-deGFP (AR-11)
# 1    B2  Concentration           pT7-deGFP 50            pT7-deGFP (AR-11)
# 2    B3  Concentration           pT7-deGFP 20            pT7-deGFP (AR-11)
# 3    B4  Concentration           pT7-deGFP 10            pT7-deGFP (AR-11)
# 4    B5  Concentration            pT7-deGFP 5            pT7-deGFP (AR-11)
# 5    B6  Concentration            pT7-deGFP 2            pT7-deGFP (AR-11)
# 6    B7  Concentration            pT7-deGFP 1            pT7-deGFP (AR-11)
# 7    B8  Concentration            pT7-deGFP 0            pT7-deGFP (AR-11)
# 8    C1       Artifact  pT7-lacO-plamGFP 29.3  pT7-lacO-plamGFP (20240622)
# 9    C2       Artifact  pT7-lacO-plamGFP 35.8  pT7-lacO-plamGFP (20240626)
# 10   C3       Artifact  pT7-lacO-plamGFP 17.1  pT7-lacO-plamGFP (20240510)
# 11   C4       Artifact  pT7-tetO-plamGFP 72.7  pT7-tetO-plamGFP (20240622)
# 12   C5       Artifact  pT7-tetO-plamGFP 46.4  pT7-tetO-plamGFP (20240626)
# 13   C6       Artifact  pT7-tetO-plamGFP 12.3  pT7-tetO-plamGFP (20240510)
# 14   C7       Artifact        pT7-deGFP 178.5            pT7-deGFP (AR-11)
# 15   C8       Artifact        pT7-deGFP 178.5            pT7-deGFP (AR-11)
#
#     [DNA Template] (ng/uL)
# 0                   100.00
# 1                    50.00
# 2                    20.00
# 3                    10.00
# 4                     5.00
# 5                     2.00
# 6                     1.00
# 7                     0.00
# 8                    29.30
# 9                    35.80
# 10                   17.10
# 11                   72.70
# 12                   46.40
# 13                   12.30
# 14                  178.50
# 15                  178.50

# %%
#| label: table1-2
data
# Out:
#      Well Row  Column            Time  Seconds  Temperature (C)     Read  \
# 0      B1   B       1 0 days 00:00:00     0.00            37.00  490,520
# 1      B1   B       1 0 days 00:05:00   300.00            37.00  490,520
# 2      B1   B       1 0 days 00:10:00   600.00            37.00  490,520
# 3      B1   B       1 0 days 00:15:00   900.00            37.00  490,520
# 4      B1   B       1 0 days 00:20:00  1200.00            37.00  490,520
# ...   ...  ..     ...             ...      ...              ...      ...
# 1163   C8   C       8 0 days 05:40:00 20400.00            37.00  490,520
# 1164   C8   C       8 0 days 05:45:00 20700.00            37.00  490,520
# 1165   C8   C       8 0 days 05:50:00 21000.00            37.00  490,520
# 1166   C8   C       8 0 days 05:55:00 21300.00            37.00  490,520
# 1167   C8   C       8 0 days 06:00:00 21600.00            37.00  490,520
#
#          Data     Experiment             Name       DNA Template  \
# 0      289.00  Concentration    pT7-deGFP 100  pT7-deGFP (AR-11)
# 1      312.00  Concentration    pT7-deGFP 100  pT7-deGFP (AR-11)
# 2      449.00  Concentration    pT7-deGFP 100  pT7-deGFP (AR-11)
# 3      982.00  Concentration    pT7-deGFP 100  pT7-deGFP (AR-11)
# 4     1880.00  Concentration    pT7-deGFP 100  pT7-deGFP (AR-11)
# ...       ...            ...              ...                ...
# 1163 16772.00       Artifact  pT7-deGFP 178.5  pT7-deGFP (AR-11)
# 1164 16751.00       Artifact  pT7-deGFP 178.5  pT7-deGFP (AR-11)
# 1165 16660.00       Artifact  pT7-deGFP 178.5  pT7-deGFP (AR-11)
# 1166 16755.00       Artifact  pT7-deGFP 178.5  pT7-deGFP (AR-11)
# 1167 16731.00       Artifact  pT7-deGFP 178.5  pT7-deGFP (AR-11)
#
#       [DNA Template] (ng/uL)
# 0                     100.00
# 1                     100.00
# 2                     100.00
# 3                     100.00
# 4                     100.00
# ...                      ...
# 1163                  178.50
# 1164                  178.50
# 1165                  178.50
# 1166                  178.50
# 1167                  178.50
#
# [1168 rows x 12 columns]
